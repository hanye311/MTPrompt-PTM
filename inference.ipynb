# %%
# !git clone https://github.com/hanye311/MTPrompt-PTM.git
# %cd MTPrompt-PTM
# !pip install -r requirements.txt
# Out:
# fatal: destination path 'MTPrompt-PTM' already exists and is not an empty directory.
# /content/MTPrompt-PTM
# ...

# %%
# !pip -q install gdown

FILE_ID = "1FfMepaY1JLUbKTZncE1u7-pm2d16IUuf"   # 换成你的文件ID
OUT = "/content/MTPrompt-PTM/best_model_13ptm_final.pth"                     # 想保存到的路径

# !gdown --fuzzy "https://drive.google.com/uc?id={FILE_ID}" -O "{OUT}"

import os
print("size:", os.path.getsize(OUT), "bytes")
# !file -b "{OUT}" || true     # 看看类型
# !ls -lh "{OUT}"
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1FfMepaY1JLUbKTZncE1u7-pm2d16IUuf
# From (redirected): https://drive.google.com/uc?id=1FfMepaY1JLUbKTZncE1u7-pm2d16IUuf&confirm=t&uuid=0a5eda03-a5ae-408f-9cb5-5c121036a8ec
# To: /content/MTPrompt-PTM/checkpoints/best_model_13ptm_final.pth
# 100% 2.96G/2.96G [00:33<00:00, 88.1MB/s]
# size: 2961418302 bytes
# Zip archive data, at least v0.0 to extract, compression method=store
# -rw-r--r-- 1 root root 2.8G Aug 12 19:59 /content/MTPrompt-PTM/checkpoints/best_model_13ptm_final.pth

# %%
# !python test.py \
  --config_path config/PTM_config_prompt_tuning_test.yaml \
  --model_path best_model_13ptm_final.pth \
  --data_path data/Phosphorylation_S_sequence.fasta \
  --PTM_type Phosphorylation_S \
  --save_path data
# Out:
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'
# Downloading: "https://dl.fbaipublicfiles.com/fair-esm/models/esm2_t33_650M_UR50D.pt" to /root/.cache/torch/hub/checkpoints/esm2_t33_650M_UR50D.pt
# Downloading: "https://dl.fbaipublicfiles.com/fair-esm/regression/esm2_t33_650M_UR50D-contact-regression.pt" to /root/.cache/torch/hub/checkpoints/esm2_t33_650M_UR50D-contact-regression.pt
# Steps: 100% 3/3 [03:31<00:00, 70.51s/it]
# The predicion has been saved in data/Phosphorylation_S_test_output.csv.
# prediction time: 211.5616500377655
